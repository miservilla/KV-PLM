# %%
import pandas as Pd

# Load the data
data = Pd.read_csv('/data_link/servilla/KV-PLM/compound_smiles.csv')
print(data)
data = data.drop_duplicates(subset='SMILES')
print(data)
data = data.dropna(subset=['SMILES'])
print(data)
data.to_csv('/data_link/servilla/KV-PLM/compound_smiles_no_dups_Nan.csv', index=False)
# Out:
#            Column Names        CID  \
# 0          8-bromo-cGMP  135419186
# 1            nifurtimox    6842999
# 2         balaglitazone    9889200
# 3          flutrimazole       3401
# 4                   KBG    6917960
# ...                 ...        ...
# 4681          xenalipin      55251
# 4682          motesanib   11667893
# 4683         lorlatinib   71731823
# 4684        deslanoside      28620
# 4685  clonixin-lysinate    3080836
#
#                                                  SMILES
# 0     C1C2C(C(C(O2)N3C4=C(C(=O)NC(=N4)N)N=C3Br)O)OP(...
# 1           CC1CS(=O)(=O)CCN1N=CC2=CC=C(O2)[N+](=O)[O-]
# 2     CN1C(=NC2=CC=CC=C2C1=O)COC3=CC=C(C=C3)CC4C(=O)...
# 3     C1=CC=C(C=C1)C(C2=CC=C(C=C2)F)(C3=CC=CC=C3F)N4...
# 4                C1C2C(C(C(C(O2)O)O)O)OC(O1)C3=CC=CC=C3
# ...                                                 ...
# 4681         C1=CC=C(C(=C1)C2=CC=C(C=C2)C(F)(F)F)C(=O)O
# 4682  CC1(CNC2=C1C=CC(=C2)NC(=O)C3=C(N=CC=C3)NCC4=CC...
# ...
